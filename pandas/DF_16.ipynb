# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakbarov7/LearnDataScienceBootcamp/blob/main/pandas/DF_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Bir ustunni qanday qiymatlari borligini ko'rish uchun agar ular takrorlanib kelgan bo'lsa , takrorlanmas qilib ko'rish
# 2. Ana shu ustundagi takrorlangan qiymatlar sonini aniqlash , masalan BClass dan nechta bor `df['ustun'].value_counts()`
# 3. Jadval ichidan bizga kerakli qiymatlarni alohida jadvalga ajratib olish mumkin , filtrlash yordamida
#
#   `models = [SLK, BClass]`
#
#   `filtr = df['ustun_model'].isin(models)` modelsdagi ikkita mashina DataFramening model ustunida bormi ? bor bo'lsa True aks holda False beradi
#
#   `print(filtr)` endi ushbu filtrni DF ga qo'llimiz
#
#   `df[filtr]` faqat SLK va BClass mashinalari ma'lumotlarini beradi , qoganini tashavoradi
# 4. `df[filtr_yozish]` ko'rinishida DF ning o'ziga filtr yozishimiz mumkin , 2 va undan ortiq shartlar berishimiz mumkin , filtrlash faqat sonlar ustida emas str dayam qisa bo'ladi bemalol

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df['model'].unique()
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' A Class', ' B Class', ' GLC Class', ' C Class',
#        ' E Class', ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#        ' V Class', ' M Class', ' CL Class', ' GLS Class', ' GLB Class',
#        ' X-CLASS', '180', ' CLK', ' R Class', '230', '220', '200'],
#       dtype=object)

# %%
df['fuelType'].unique()
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Other'], dtype=object)

# %%
df['model'].value_counts()
# Out:
# model
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: count, dtype: int64

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# Diesel    9187
# Petrol    3752
# Hybrid     173
# Other        7
# Name: count, dtype: int64

# %%
# faqat A Class va GL Class mashinalarga oid ma'lumotlarni alohida jadval qilib olish
model = [' A Class', ' GL Class']
filtr = df['model'].isin(model)
filtr.sample(10)
# Out:
# 2494     False
# 2633     False
# 12982    False
# 8994     False
# 6695      True
# 8962     False
# 2001      True
# 12119    False
# 10153    False
# 12615     True
# Name: model, dtype: bool

# %%
df[filtr]
# Out:
#            model  year   price transmission  mileage fuelType  tax   mpg  \
# 10       A Class  2020   32980    Automatic      606   Petrol  145  35.8
# 11       A Class  2020   26980    Automatic     1000   Diesel  145  62.8
# 24      GL Class  2015   34129    Automatic    13581   Diesel  330  36.2
# 33       A Class  2020   28128    Automatic     2563   Petrol  145  47.9
# 34       A Class  2019   23184       Manual     1173   Petrol  145  44.8
# ...          ...   ...     ...          ...      ...      ...  ...   ...
# 13060    A Class  2017  109495    Automatic     1755   Petrol  145  24.8
# 13066    A Class  2019   23440    Automatic    10124   Petrol  145  53.3
# 13083   GL Class  2015   31723    Automatic    31112   Diesel  330  36.2
# 13090    A Class  2015   12995    Automatic    34665   Diesel   20  70.6
# 13109    A Class  2017   16499    Automatic    20477   Diesel  145  68.9
#
#        engineSize
# 10            2.0
# 11            1.5
# 24            3.0
# ...

# %%
df.sample(10)
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 12879     C Class  2017  14900    Automatic    27287   Petrol  125  53.3
# 10424     C Class  2017  23700    Automatic    19832   Diesel  125  61.4
# 8940     SL CLASS  2017  39999    Semi-Auto    19200   Petrol  145  31.4
# 12139     C Class  2017  17400    Automatic    24653   Diesel   30  61.4
# 2631    GLC Class  2019  43591    Automatic     5326   Diesel  145  40.9
# 9987      C Class  2013  10999    Automatic    49085   Diesel  145  53.3
# 7152      B Class  2019  22299    Semi-Auto    12429   Petrol  145  45.6
# 6334      C Class  2016  31945    Automatic    34765   Petrol  260  35.3
# 9452     CL Class  2019  26199    Semi-Auto    12441   Diesel  145  51.4
# 12385   CLA Class  2017  15600       Manual    22171   Petrol  145  51.4
#
#        engineSize
# 12879         2.0
# 10424         2.1
# 8940          4.7
# 12139         2.1
# 2631          2.0
# 9987          2.1
# 7152          1.3
# ...

# %%
df[df['price'] < 35000]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 6       GLE Class  2018  30948    Automatic    16000   Diesel  145  47.9
# 7         S Class  2012  10948    Automatic   107000   Petrol  265  36.7
# 9       GLA Class  2017  19750    Automatic    15258   Diesel   30  64.2
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13111     B Class  2019  19344    Automatic    15257   Petrol  145  45.6
# 13112     C Class  2019  30399    Automatic     5000   Diesel  145  61.4
# 13113     C Class  2020  30999    Automatic     1000   Diesel  145  64.2
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
#
#        engineSize
# 0             1.8
# 1             2.1
# 6             2.1
# ...

# %%
df[(df['fuelType'] == 'Petrol') & (df['price'] < 25000)]
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 7        S Class  2012  10948    Automatic   107000   Petrol  265  36.7
# 28      SL CLASS  2018  22914    Automatic     8725   Petrol  145  47.9
# 34       A Class  2019  23184       Manual     1173   Petrol  145  44.8
# 40           SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 13076    C Class  2019  23948    Automatic    16496   Petrol  145  46.3
# 13093    C Class  2019  23999    Automatic     6328   Petrol  145  46.3
# 13098    C Class  2019  24499    Automatic    10635   Petrol  145  44.1
# 13099    C Class  2019  23994    Automatic    12794   Petrol  145  46.3
# 13111    B Class  2019  19344    Automatic    15257   Petrol  145  45.6
#
#        engineSize
# 0             1.8
# 7             3.5
# 28            2.0
# 34            1.3
# ...

# %%
df[(df['fuelType'] == 'Hybrid') & (df['engineSize'] == 2.0)]
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 137     C Class  2017  21000    Automatic    25000   Hybrid  140  134.5
# 327     E Class  2019  39998    Semi-Auto     2675   Hybrid  135  134.5
# 329     C Class  2016  18498    Semi-Auto    31891   Hybrid    0  134.5
# 413     C Class  2016  17998    Semi-Auto    36587   Hybrid    0  134.5
# 427     C Class  2016  19698    Automatic    25107   Hybrid    0  134.5
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 12105   C Class  2017  17890    Automatic    45437   Hybrid    0  134.5
# 12683   E Class  2019  35890    Automatic     8797   Hybrid  135  134.5
# 12687   C Class  2017  17480    Automatic    47019   Hybrid    0  134.5
# 12713   C Class  2017  20480    Automatic    30053   Hybrid    0  134.5
# 12999   C Class  2016  15999    Automatic    66077   Hybrid    0  134.5
#
#        engineSize
# 137           2.0
# 327           2.0
# 329           2.0
# 413           2.0
# ...
