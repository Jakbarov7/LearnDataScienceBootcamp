# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakbarov7/LearnDataScienceBootcamp/blob/main/pandas/DF_7_les.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Elementlarni tanlash:
# - DF ning bir ustunini Series ko'rinishida olish
# - bir ustunni DF ko'rinishida olish
# - bir ustunni Series qilib keyin numpyga o'girish
# - bir qancha ustunni DF qilib olish
# - istalgan qatorlarni DF qilib olish
# - filtrlash
# - bir ustunni DF qilib olib , o'shani ustida ham filtrlash mumkin
# - DF ustun va indekslar o'rnini almashtirish

# %%
# DF yaratamiz
data = {
    'USA': {
        2020: 331002651,
        2021: 331893745,
        2022: 332915073,
        2023: 334035655,
        2024: 335154543
    },
    'India': {
        2020: 1380004385,
        2021: 1393409038,
        2022: 1407563842,
        2023: 1421339190,
        2024: 1433783686
    },
    'China': {
        2020: 1444216107,
        2021: 1448471400,
        2022: 1453780764,
        2023: 1459453821,
        2024: 1465837300
    },
    'Brazil': {
        2020: 212559417,
        2021: 213993437,
        2022: 215353593,
        2023: 216688182,
        2024: 217999573
    },
    'Nigeria': {
        2020: 206139589,
        2021: 208679114,
        2022: 211400708,
        2023: 214028302,
        2024: 216746934
    }
}
df = pd.DataFrame(data)
df
# Out:
#             USA       India       China     Brazil    Nigeria
# 2020  331002651  1380004385  1444216107  212559417  206139589
# 2021  331893745  1393409038  1448471400  213993437  208679114
# 2022  332915073  1407563842  1453780764  215353593  211400708
# 2023  334035655  1421339190  1459453821  216688182  214028302
# 2024  335154543  1433783686  1465837300  217999573  216746934

# %%
# bir ustunni Series qilib olish
df['Brazil']
# Out:
# 2020    212559417
# 2021    213993437
# 2022    215353593
# 2023    216688182
# 2024    217999573
# Name: Brazil, dtype: int64

# %%
# bir ustunni DataFrame qilib olish | ikkitalik to'rtburchak qavs ichiga yozamiz
df[['Brazil']]
# Out:
#          Brazil
# 2020  212559417
# 2021  213993437
# 2022  215353593
# 2023  216688182
# 2024  217999573

# %%
# bir ustun qiymatlarini numpy qilib olish | birinchi Series qilib keyin numpy qilamiz
df['USA'].to_numpy()
# Out:
# array([331002651, 331893745, 332915073, 334035655, 335154543])

# %%
# bir vaqtda bir qancha ustunlarni DF qilib olish | 2 talik qavs ichiga yozamiz
df[['USA', 'Brazil', 'India']]
# Out:
#             USA     Brazil       India
# 2020  331002651  212559417  1380004385
# 2021  331893745  213993437  1393409038
# 2022  332915073  215353593  1407563842
# 2023  334035655  216688182  1421339190
# 2024  335154543  217999573  1433783686

# %%
# indeks_tartib_raqam bo'yicha - istalgan qatorlarni DF qilib olish
df[3:] # 3-indeksdan boshlab hammasini DF qilib oberadi
# Out:
#             USA       India       China     Brazil    Nigeria
# 2023  334035655  1421339190  1459453821  216688182  214028302
# 2024  335154543  1433783686  1465837300  217999573  216746934

# %%
df
# Out:
#             USA       India       China     Brazil    Nigeria
# 2020  331002651  1380004385  1444216107  212559417  206139589
# 2021  331893745  1393409038  1448471400  213993437  208679114
# 2022  332915073  1407563842  1453780764  215353593  211400708
# 2023  334035655  1421339190  1459453821  216688182  214028302
# 2024  335154543  1433783686  1465837300  217999573  216746934

# %%
# Filtrlash
df[df.USA > 332000000]
# Out:
#             USA       India       China     Brazil    Nigeria
# 2022  332915073  1407563842  1453780764  215353593  211400708
# 2023  334035655  1421339190  1459453821  216688182  214028302
# 2024  335154543  1433783686  1465837300  217999573  216746934

# %%
# bir ustunni DF qilib olib , uni ustida ham filtrlash mumkin
df_b = df[['Brazil']]
df_b[df_b['Brazil']>215353593]
# Out:
#          Brazil
# 2023  216688182
# 2024  217999573
