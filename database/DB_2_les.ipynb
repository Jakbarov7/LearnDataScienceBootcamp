# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakbarov7/LearnDataScienceBootcamp/blob/main/database/DB_2_les.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df = pd.read_excel('praktikum_datasets/uzbekistan.xlsx', names=['huhud','maydon','aholi'], index_col=0)
df
# Out:
#                                maydon    aholi
# huhud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
# faylga yozish
df.to_csv("uzb_info.csv")

# %%
# jadvaldagi kerakli ustunni ham alohida faylga yozb olish mumkin
obj = df.aholi
obj
# Out:
# huhud
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: aholi, dtype: int64

# %%
obj.to_csv("uzb_aholisi.csv")

# %%
# ana shu obj ni o'qiymiz
pd.read_csv("uzb_aholisi.csv")
# Out:
#                             huhud    aholi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2               Fargʻona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %%
# yuqoridagi Series faylni , Series qilib o'qish
aholi = pd.read_csv("uzb_aholisi.csv", index_col=0)
if aholi.shape[1] == 1:
    aholi = aholi.squeeze('columns')
aholi
# Out:
# huhud
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: aholi, dtype: int64

# %%
df
# Out:
#                                maydon    aholi
# huhud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
# csv jadvalni excel ko'rinishidayam saqlash mumkin
df.to_excel("df.xlsx", index=False)

# %%
# faylni saqlayotganda faqat bizga kerakli ma'lumotlarnigini ajratib saqlashimiz mumkin
df.to_excel("newinfo.xlsx", index=False, columns=['aholi'])

# %%
# faylni papkaga saqlash
df.to_excel("praktikum_datasets/newinfo.xlsx", index=False, columns=['aholi'])
