# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakbarov7/LearnDataScienceBootcamp/blob/main/database/DB_4_les.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Web sahifalardan o'qish**

# %%
# wikipedyadan o'qimiz
web = pd.read_html("https://en.wikipedia.org/wiki/W3Schools")

# %%
# web o'zgaruvchisi bizda dataframelar saqlangan list bo'ladi
type(web)
# Out:
# list

# %%
# ichida nechta daraframelar borligini aniqlimiz
len(web)
# Out:
# 3

# %%
# ichidagi jadvallarni ko'rib chiqamiz
web[0]
# Out:
#                 0                       1
# 0             NaN                     NaN
# 1    Type of site  Web development portal
# 2    Available in      Multiple languages
# 3           Owner         Refsnes Data AS
# 4      Created by         Refsnes Data AS
# 5             URL       www.w3schools.com
# 6      Commercial                     Yes
# 7    Registration      Required for forum
# 8        Launched      1998; 26 years ago
# 9  Current status                  Active

# %%
web[2]
# Out:
#     0                                                  1
# 0 NaN  This World Wide Web–related article is a stub....

# %%
web[1]
# Out:
#     0                                                  1
# 0 NaN  This article about an educational website is a...

# %%
# Uzb haqidagi sahifani o'qimiz
uzb = pd.read_html("https://en.wikipedia.org/wiki/Uzbekistan")

# %%
type(uzb)
# Out:
# list

# %%
len(uzb)
# Out:
# 27

# %%
uzb[4]
# Out:
#    Largest cities or towns in Uzbekistan                                \
#                       Unnamed: 0_level_1               Rank       Name
# 0                      Tashkent Namangan                  1   Tashkent
# 1                      Tashkent Namangan                  2   Namangan
# 2                      Tashkent Namangan                  3  Samarkand
# 3                      Tashkent Namangan                  4    Andijan
# 4                      Tashkent Namangan                  5      Nukus
# 5                      Tashkent Namangan                  6    Fergana
# 6                      Tashkent Namangan                  7    Bukhara
# 7                      Tashkent Namangan                  8     Qarshi
# 8                      Tashkent Namangan                  9     Kokand
# 9                      Tashkent Namangan                 10   Margilan
# 10                     Tashkent Namangan  Samarkand Andijan        NaN
#
# ...

# %%
uzb[12]
# Out:
#           vteEconomic Cooperation Organization (ECO)  \
# 0                                           Politics
# 1  ECOTA Secretariat Secretaries-General Treaty o...
# 2                                            Symbols
# 3                                            Summits
# 4                                             Member
# 5                                          Observers
#
#         vteEconomic Cooperation Organization (ECO).1
# 0  ECOTA Secretariat Secretaries-General Treaty o...
# 1  ECOTA Secretariat Secretaries-General Treaty o...
# 2                                        Emblem Flag
# 3  Tehran 1992 Istanbul 1993 Islamabad 1995 Ashga...
# 4  Afghanistan  Azerbaijan  Iran  Kazakhstan  Kyr...
# 5         Northern Cyprus (as Turkish Cypriot State)

# %%
uzb[23]
# Out:
#   vte Organization of Turkic States  \
# 0                           Members
# 1                         Observers
# 2                           Summits
# 3                           Symbols
# 4                             Award
#
#                  vte Organization of Turkic States.1  \
# 0  Azerbaijan  Kazakhstan  Kyrgyzstan  Turkey  Uz...
# 1             Hungary  Northern Cyprus  Turkmenistan
# 2  Turkic Speaking States summits (1992-2010) Tur...
# 3     Flag Turkic Speaking Countries Cooperation Day
# 4                      Supreme Order of Turkic World
#
#    vte Organization of Turkic States.2
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
