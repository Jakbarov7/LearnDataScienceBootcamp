# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakbarov7/LearnDataScienceBootcamp/blob/main/database/DB_5_les.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **JSON va API dan o'qish**

# %%
# collabdagi json faylni o'qish
f = pd.read_json("file.json")

# %%
f.sample(7)
# Out:
#                 someone         slide     dark   substance  bank  pressure  \
# saved        1794271337  1.917367e+09  however        True  True      True
# sat          1794271337  1.917367e+09  however       local  True      True
# threw        1794271337  1.917367e+09  however       False  True      True
# needs        1794271337  1.917367e+09  however  1045740936  True      True
# mathematics  1794271337  1.917367e+09  however        dirt  True      True
# log          1794271337  1.917367e+09  however   satisfied  True      True
# real         1794271337  1.917367e+09  however       False  True      True
#
#                     music     ball  region appropriate  ...  notice  husband  \
# saved        2.116869e+09  problem   False        form  ...    dawn    False
# sat          2.116869e+09  problem   False        form  ...    dawn    False
# threw        2.116869e+09  problem   False        form  ...    dawn    False
# ...

# %%
f.shape
# Out:
# (35, 35)

# %%
# API dan JSON olish
import requests
r = requests.get("https://openlibrary.org/subjects/time.json?published_in=2000-2020")

# %%
# yuqoridagi ssilkamiz ishladimi yo'qmi tekshirish
r.status_code
# Out:
# 200

# %%
# qiymatlarni ko'rish
r.json()
# Out:
# {'key': '/subjects/time',
#  'name': 'time',
#  'subject_type': 'subject',
#  'work_count': 2749,
#  'works': [{'key': '/works/OL137872W',
#    'title': 'Confessions',
#    'edition_count': 449,
#    'cover_id': 9022521,
#    'cover_edition_key': None,
#    'subject': ['Religious aspects of Truth',
#     'Christian saints',
#     'Christianity',
#     'Spiritual life',
#     'Religion & Spirituality',
#     'Bishop of Hippo',
#     'Hippo',
#     'Collected works',
#     'Christian life',
#     'Early church',
#     'Inspiration',
#     'Bishops',
#     'Theology',
#     'Mass',
#     'Truth',
#     'Time',
#     'Extinct city',
#     'Catholic Church',
#     'Early works to 1800',
#     'Nonfiction',
#     'Saint Augustine',
#     'Biography & Autobiography',
#     'Religious aspects of Inspiration',
#     'Biography',
#     'Oriya literature',
#     'History and criticism',
#     'General',
#     'Fiction - General',
#     'Religion',
#     'Augustine,',
# ...

# %%
# DataFrame jadval ko'rinishida olish
pd.DataFrame(r.json())
# Out:
#                key  name subject_type  work_count  \
# 0   /subjects/time  time      subject        2749
# 1   /subjects/time  time      subject        2749
# 2   /subjects/time  time      subject        2749
# 3   /subjects/time  time      subject        2749
# 4   /subjects/time  time      subject        2749
# 5   /subjects/time  time      subject        2749
# 6   /subjects/time  time      subject        2749
# 7   /subjects/time  time      subject        2749
# 8   /subjects/time  time      subject        2749
# 9   /subjects/time  time      subject        2749
# 10  /subjects/time  time      subject        2749
# 11  /subjects/time  time      subject        2749
#
#                                                 works
# 0   {'key': '/works/OL137872W', 'title': 'Confessi...
# 1   {'key': '/works/OL1892617W', 'title': 'A Brief...
# 2   {'key': '/works/OL2271626W', 'title': 'Momo od...
# 3   {'key': '/works/OL2965102W', 'title': 'The Cur...
# ...

# %%
# jadvaldan kerakli ustunni olish
# works ustunini olamiz
r.json()['works']
# Out:
# [{'key': '/works/OL137872W',
#   'title': 'Confessions',
#   'edition_count': 449,
#   'cover_id': 9022521,
#   'cover_edition_key': None,
#   'subject': ['Religious aspects of Truth',
#    'Christian saints',
#    'Christianity',
#    'Spiritual life',
#    'Religion & Spirituality',
#    'Bishop of Hippo',
#    'Hippo',
#    'Collected works',
#    'Christian life',
#    'Early church',
#    'Inspiration',
#    'Bishops',
#    'Theology',
#    'Mass',
#    'Truth',
#    'Time',
#    'Extinct city',
#    'Catholic Church',
#    'Early works to 1800',
#    'Nonfiction',
#    'Saint Augustine',
#    'Biography & Autobiography',
#    'Religious aspects of Inspiration',
#    'Biography',
#    'Oriya literature',
#    'History and criticism',
#    'General',
#    'Fiction - General',
#    'Religion',
#    'Augustine,',
#    'Religion - Classic Works',
#    'Saint, Bishop of Hippo',
#    'Hippo (Extinct city)',
#    'Augustine',
#    'Algeria',
#    'Biographies',
# ...

# %%
# jadval ko'rinishida olish
pd.DataFrame(r.json()['works']).sample(7)
# Out:
#                   key                                              title  \
# 2   /works/OL2271626W  Momo oder Die seltsame Geschichte von den Zeit...
# 3   /works/OL2965102W  The Curious Incident of the Dog in the Night-Time
# 4   /works/OL2234905W                                      Strong Poison
# 9   /works/OL4720160W                               Time Traveler's Wife
# 10    /works/OL37703W                                           Pandosto
# 8     /works/OL46402W                                  Pebble in the Sky
# 1   /works/OL1892617W                            A Brief History of Time
#
#     edition_count  cover_id cover_edition_key  \
# 2             108   8574580       OL26316477M
# 3             102   7890719        OL3563061M
# 4              80     43788        OL9241603M
# 9              36   9273734       OL27914527M
# 10             33   9959158        OL7002400M
# 8              42   6550102       OL24216404M
# 1             115  10432365       OL19989976M
#
# ...
